# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128),
  tf.keras.layers.Lambda(lambda x: tf.abs(x)), 
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2213 - accuracy: 0.9377
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0902 - accuracy: 0.9727
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0635 - accuracy: 0.9809
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0493 - accuracy: 0.9843
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0383 - accuracy: 0.9873
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0910 - accuracy: 0.9753
# [0.09101405739784241, 0.9753000140190125]

# %%
def my_relu(x):
    return K.maximum(-0.1, x)

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128),
    tf.keras.layers.Lambda(my_relu), 
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2594 - accuracy: 0.9261
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1129 - accuracy: 0.9664
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0790 - accuracy: 0.9762
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0588 - accuracy: 0.9821
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0452 - accuracy: 0.9862
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0796 - accuracy: 0.9759
# [0.07957616448402405, 0.9758999943733215]
